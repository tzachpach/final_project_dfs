# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import logging
import numpy as np
import pandas as pd
import os
import pickle
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Flatten, Concatenate, Dropout

# %% [markdown]
# # Constants

# %%
rolling_window = 10

dfs_cats = ['reb', 'pts', 'ast', 'stl', 'blk', 'tov']
same_game_cols = ['minutes_played', 'fgm', 'fga', 'fg_pct', 'fg3m', 'fg3a', 'fg3_pct', 'ftm', 'fta', 'ft_pct', 'oreb',
                   'dreb', 'reb', 'ast', 'tov', 'stl', 'blk', 'blka', 'pf', 'pfd', 'pts', 'plus_minus',
                   'nba_fantasy_pts', 'dd2', 'td3', 'wnba_fantasy_pts', 'available_flag', 'e_off_rating', 'off_rating',
                   'sp_work_off_rating', 'e_def_rating', 'def_rating', 'sp_work_def_rating', 'e_net_rating',
                   'net_rating', 'sp_work_net_rating', 'ast_pct', 'ast_to', 'ast_ratio', 'oreb_pct', 'dreb_pct',
                   'reb_pct', 'tm_tov_pct', 'e_tov_pct', 'efg_pct', 'ts_pct', 'usg_pct_x', 'e_usg_pct', 'e_pace',
                   'pace', 'pace_per40', 'sp_work_pace', 'pie', 'poss', 'fgm_pg', 'fga_pg', 'pct_fga_2pt',
                   'pct_fga_3pt', 'pct_pts_2pt', 'pct_pts_2pt_mr', 'pct_pts_3pt', 'pct_pts_fb', 'pct_pts_ft',
                   'pct_pts_off_tov', 'pct_pts_paint', 'pct_ast_2pm', 'pct_uast_2pm', 'pct_ast_3pm', 'pct_uast_3pm',
                   'pct_ast_fgm', 'pct_uast_fgm', 'pct_fgm', 'pct_fga', 'pct_fg3m', 'pct_fg3a', 'pct_ftm', 'pct_fta',
                   'pct_oreb', 'pct_dreb', 'pct_reb', 'pct_ast', 'pct_tov', 'pct_stl', 'pct_blk', 'pct_blka', 'pct_pf',
                   'pct_pfd', 'pct_pts', 'usage_rate', 'fp_draftkings', 'fp_fanduel',
                   'fp_yahoo']

# %%
def assign_league_weeks(df):
    df['week'] = df['game_date'].dt.isocalendar().week
    df['season_start'] = df.groupby('season_year')['game_date'].transform('min')
    df['season_week'] = ((df['game_date'] - df['season_start']).dt.days // 7) + 1
    df = df.drop(columns=['season_start', 'week'])
    df = df.rename(columns={'season_week': 'league_week'})
    return df

# %%
def create_sequences(X, y, time_steps):
    Xs, ys = [], []
    for i in range(len(X) - time_steps + 1):
        Xs.append(X.iloc[i:(i + time_steps)].values)
        ys.append(y.iloc[i + time_steps - 1])  # Adjusted this line
    return np.array(Xs), np.array(ys)

# %%
def build_rnn_model(input_shape):
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dense(25))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
def rolling_train_test_rnn(X, y, df, num_weeks_for_training=4, time_steps=4, save_model=False, model_dir='models'):
    os.makedirs(model_dir, exist_ok=True)

    # Initialize lists to store predictions and true values
    all_predictions = []
    all_true_values = []
    all_game_ids = []
    all_game_dates = []
    all_player_ids = []
    all_fanduel_salaries = []
    all_draftkings_salaries = []
    all_yahoo_salaries = []
    all_fanduel_positions = []
    all_draftkings_positions = []
    all_yahoo_positions = []

    scaler = MinMaxScaler(feature_range=(0, 1))
    unique_weeks = df['league_week'].unique()

    for current_week in unique_weeks:
        start_week = current_week - num_weeks_for_training
        training_weeks = list(range(start_week, current_week))

        # Select training data (previous 4 weeks)
        X_train = X[X['league_week'].isin(training_weeks)]
        y_train = y.loc[X_train.index]

        # Select test data (current week)
        X_test = X[X['league_week'] == current_week]
        y_test = y.loc[X_test.index]

        if X_train.empty or X_test.empty:
            continue

        identifying_test_data = X_test[['player_name', 'game_date', 'game_id']]
        X_train = X_train.drop(columns=['game_date', 'game_id'])
        X_test = X_test.drop(columns=['game_date', 'game_id'])

        # Scale data
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        # Create sequences for training
        X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, time_steps)
        X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, time_steps)

        # Build and train the RNN model
        model = build_rnn_model((X_train_seq.shape[1], X_train_seq.shape[2]))
        model.fit(X_train_seq, y_train_seq, epochs=10, batch_size=32, verbose=0)

        # Make predictions
        y_pred = model.predict(X_test_seq)

        # Store the predictions and true values
        all_predictions.extend(y_pred.flatten())
        all_true_values.extend(y_test_seq)
        all_game_ids.extend(list(identifying_test_data['game_id'])[time_steps:])
        all_game_dates.extend(list(identifying_test_data['game_date'])[time_steps:])
        all_player_ids.extend(list(identifying_test_data['player_name'])[time_steps:])
        all_fanduel_salaries.extend(X_test['salary-draftkings'].values[time_steps:])
        all_draftkings_salaries.extend(X_test['salary-draftkings'].values[time_steps:])
        all_yahoo_salaries.extend(X_test['salary-yahoo'].values[time_steps:])
        all_fanduel_positions.extend(X_test['pos-draftkings'].values[time_steps:])
        all_draftkings_positions.extend(X_test['pos-draftkings'].values[time_steps:])
        all_yahoo_positions.extend(X_test['pos-yahoo'].values[time_steps:])

        if save_model:
            model_filename = f'{model_dir}/rnn_model_week_{current_week}_trained_on_{start_week}_to_{current_week - 1}.h5'
            model.save(model_filename)

        mse = mean_squared_error(y_test_seq, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_seq, y_pred)

        print(f'Training weeks: {training_weeks}')
        print(f'Test week: {current_week}')
        print(f'Mean Squared Error (MSE): {mse:.2f}')
        print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
        print(f'R-squared (R²): {r2:.2f}')
        print('')

    results_df = pd.DataFrame({
        'player_name': all_player_ids,
        'game_id': all_game_ids,
        'game_date': all_game_dates,
        'y': all_true_values,
        'y_pred': all_predictions,
        'fanduel_salary': all_fanduel_salaries,
        'draftkings_salary': all_draftkings_salaries,
        'yahoo_salary': all_yahoo_salaries,
        'fanduel_position': all_fanduel_positions,
        'draftkings_position': all_draftkings_positions,
        'yahoo_position': all_yahoo_positions,
    })

    return results_df

# %%
def predict_fp_rnn(df, rolling_window=rolling_window):
    df = df.drop('Unnamed: 0', axis=1)
    df['game_date'] = pd.to_datetime(df['game_date'])

    cat_cols = ['team_abbreviation', 'player_name', 'opponent', 'pos-draftkings', 'pos-fanduel', 'pos-yahoo']
    df[cat_cols] = df[cat_cols].astype('category')

    df = df.sort_values(['game_date'], ascending=True)
    df = assign_league_weeks(df)
    df = clean_numeric_columns(df, same_game_cols)
    df = add_time_dependent_features(df, rolling_window=rolling_window)

    all_seasons_results = []

    for season in df['season_year'].unique():
        season_df = df[df['season_year'] == season]
        season_df = season_df.drop('season_year', axis=1)
        season_results = pd.DataFrame()

        for cat in dfs_cats:
            target = cat
            target_related_cols = same_game_cols
            features = season_df.columns.difference(target_related_cols).tolist()

            X = season_df[features]
            y = season_df[target]

            print(f'Training RNN models for {cat}')
            print('---------------------------------')
            cat_results = rolling_train_test_rnn(X=X, y=y, df=season_df)
            cat_results.rename(columns={'y': cat, 'y_pred': f'{cat}_pred'}, inplace=True)
            if len(season_results) == 0:
                season_results = cat_results
            else:
                season_results = pd.merge(
                    season_results,
                    cat_results,
                    on=['player_name', 'game_date', 'game_id', 'fanduel_salary', 'draftkings_salary', 'yahoo_salary', 'draftkings_position', 'fanduel_position', 'yahoo_position'],
                    suffixes=('', f'_{season_df.columns.name}'))
            cat_results.to_csv(f'output_csv/{cat}_{season}_rnn_results.csv', index=False)

        all_seasons_results.append(season_results)

    combined_df = pd.concat(all_seasons_results, ignore_index=True)
    combined_df['fp_fanduel'] = combined_df.apply(lambda row: calculate_fp_fanduel(row), axis=1)
    combined_df['fp_fanduel_pred'] = combined_df.apply(lambda row: calculate_fp_fanduel(row, pred_mode=True), axis=1)

    combined_df['fp_yahoo'] = combined_df.apply(calculate_fp_yahoo, axis=1)
    combined_df['fp_yahoo_pred'] = combined_df.apply(lambda row: calculate_fp_yahoo(row, pred_mode=True), axis=1)

    combined_df['fp_draftkings'] = combined_df.apply(calculate_fp_draftkings, axis=1)
    combined_df['fp_draftkings_pred'] = combined_df.apply(lambda row: calculate_fp_draftkings(row, pred_mode=True),
                                                          axis=1)
    return combined_df

# %%
def calculate_fp_fanduel(row, pred_mode=False):
    pred = '_pred' if pred_mode else ''
    return (row[f'pts{pred}'] +
            row[f'reb{pred}'] * 1.2 +
            row[f'ast{pred}'] * 1.5 +
            row[f'stl{pred}'] * 3 +
            row[f'blk{pred}'] * 3 -
            row[f'tov{pred}'] * 1)


def calculate_fp_yahoo(row, pred_mode=False):
    pred = '_pred' if pred_mode else ''
    return (row[f'pts{pred}'] +
            row[f'reb{pred}'] * 1.2 +
            row[f'ast{pred}'] * 1.5 +
            row[f'stl{pred}'] * 3 +
            row[f'blk{pred}'] * 3 -
            row[f'tov{pred}'] * 1)


def calculate_fp_draftkings(row, pred_mode=False):
    pred = '_pred' if pred_mode else ''
    fp = (row[f'pts{pred}'] +
          row[f'reb{pred}'] * 1.25 +
          row[f'ast{pred}'] * 1.5 +
          row[f'stl{pred}'] * 2 +
          row[f'blk{pred}'] * 2 -
          row[f'tov{pred}'] * 0.5)

    # Calculate Double-Double and Triple-Double bonuses
    stats = [row[f'pts{pred}'], row[f'reb{pred}'], row[f'ast{pred}'], row[f'stl{pred}'], row[f'blk{pred}']]
    double_double = sum([1 for stat in stats if stat >= 10]) >= 2
    triple_double = sum([1 for stat in stats if stat >= 10]) >= 3

    if double_double:
        fp += 1.5
    if triple_double:
        fp += 3

    return fp

def clean_numeric_columns(df, columns):
    """
    Convert columns to numeric, forcing errors to NaN, and handle specific non-numeric values.
    """
    for col in columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN
    return df

def add_time_dependent_features(df, rolling_window):
    for col in same_game_cols:
        logging.info(f"Adding features to {col}")
        gb = df.groupby('player_name')[col]
        df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
            lambda x: x.rolling(rolling_window, min_periods=1).mean())
        df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
            lambda x: x.rolling(rolling_window, min_periods=1).std())
        df[f'{col}_lag_1'] = gb.shift(1)
        df[f'{col}_lag_2'] = gb.shift(2)
        df[f'{col}_lag_3'] = gb.shift(3)
        df[f'{col}_diff_1'] = gb.diff(1)
        df[f'{col}_diff_2'] = gb.diff(2)
        df[f'{col}_diff_3'] = gb.diff(3)
    return df

# %% [markdown]
# # Load

# %%
df = pd.read_csv('gamelogs_salaries_2018-19_merged.csv')
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#       season_year       player_name team_abbreviation   game_id  \
# 0         2018-19   Nemanja Bjelica               SAC  21801230
# 1         2018-19      Corey Brewer               SAC  21801230
# 2         2018-19     Yuta Watanabe               MEM  21801225
# 3         2018-19      Lou Williams               LAC  21801229
# 4         2018-19      Jamal Murray               DEN  21801228
# ...           ...               ...               ...       ...
# 25607     2018-19       Aron Baynes               BOS  21800001
# 25608     2018-19      Jerami Grant               OKC  21800002
# 25609     2018-19    Raymond Felton               OKC  21800002
# 25610     2018-19      Amir Johnson               PHI  21800001
# 25611     2018-19  Alfonzo McKinnie               GSW  21800002
#
#                  game_date  minutes_played  fgm  fga  fg_pct  fg3m  ...  \
# 0      2019-04-10T00:00:00       11.910000    3    4   0.750     2  ...
# 1      2019-04-10T00:00:00       23.450000    0    0   0.000     0  ...
# 2      2019-04-10T00:00:00       19.166667    2    8   0.250     0  ...
# 3      2019-04-10T00:00:00       23.316667    5   17   0.294     1  ...
# 4      2019-04-10T00:00:00       34.583333    6   12   0.500     3  ...
# ...                    ...             ...  ...  ...     ...   ...  ...
# 25607  2018-10-16T00:00:00       19.233333    3    7   0.429     2  ...
# 25608  2018-10-16T00:00:00       29.103333    2    7   0.286     1  ...
# 25609  2018-10-16T00:00:00       13.916667    1    5   0.200     0  ...
# 25610  2018-10-16T00:00:00       11.183333    1    1   1.000     0  ...
# 25611  2018-10-16T00:00:00        2.350000    0    1   0.000     0  ...
#
#        salary-fanduel  salary-yahoo  fp_draftkings  fp_fanduel  fp_yahoo  \
# 0              4100.0          15.0          12.50        11.5      11.5
# 1              3500.0          10.0           8.25         8.7       8.7
# 2              3500.0          10.0           9.00         8.8       8.8
# 3              6700.0          26.0          27.75        25.5      25.5
# 4              7000.0          25.0          40.00        38.1      38.1
# ...               ...           ...            ...         ...       ...
# 25607          3500.0          11.0          18.00        16.3      16.3
# 25608          4700.0          10.0          19.00        21.4      21.4
# 25609          3600.0          10.0          10.25         9.1       9.1
# 25610          3500.0          10.0          10.25        10.1      10.1
# 25611          3500.0          10.0           0.00         0.0       0.0
#
#        starter  venue  is_playoff  is_wl  days_rest_int
# 0            1      0           0      0              2
# 1            0      0           0      0              2
# 2            0      1           0      0              4
# 3            0      1           0      0              2
# 4            1      1           0      0              0
# ...        ...    ...         ...    ...            ...
# 25607        0      1           0      0              3
# 25608        0      0           0      0              3
# 25609        0      0           0      0              3
# 25610        0      0           0      0              3
# 25611        0      1           0      0              3
#
# [25612 rows x 109 columns]

# %%
# prompt: find columns with missing values

# Check for missing values in each column
missing_values = df.isnull().sum()

# Filter for columns with missing values
columns_with_missing_values = missing_values[missing_values > 0]

print(columns_with_missing_values)
# Out:
# pos-draftkings       717
# pos-fanduel          121
# pos-yahoo             47
# salary-draftkings    717
# salary-fanduel       121
# salary-yahoo          47
# dtype: int64

# %%
df['game_date'] = pd.to_datetime(df['game_date'])

# %%
from sklearn.preprocessing import LabelEncoder

cat_cols = ['team_abbreviation', 'player_name', 'opponent', 'pos-draftkings', 'pos-fanduel', 'pos-yahoo']

# Create a label encoder for each categorical column
label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Flatten, Concatenate

# Define input layers for each categorical feature
inputs = []
embeddings = []
for col in cat_cols:
    input_dim = df[col].nunique()  # number of unique categories
    output_dim = min(50, input_dim // 2)  # embedding size, you can adjust this
    input_layer = Input(shape=(1,))
    embedding_layer = Embedding(input_dim=input_dim, output_dim=output_dim, input_length=1)(input_layer)
    embedding_layer = Flatten()(embedding_layer)
    inputs.append(input_layer)
    embeddings.append(embedding_layer)

# Combine all embeddings
combined_embeddings = Concatenate()(embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
combined_embeddings
# Out:
# <KerasTensor shape=(None, 91), dtype=float32, sparse=False, name=keras_tensor_29>

# %%
df = df.sort_values(['game_date'], ascending=True)
df = assign_league_weeks(df)
df = clean_numeric_columns(df, same_game_cols)
df = add_time_dependent_features(df, rolling_window=rolling_window)
# Out:
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# ...
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-19-d08f6c406a38>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb = df.groupby('player_name')[col]
# <ipython-input-19-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-19-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-19-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-19-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-19-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-19-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-19-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)

# %%
# prompt: show me all columns with missing values and their count

# Check for missing values in each column
missing_values = df.isnull().sum()

# Filter for columns with missing values
columns_with_missing_values = missing_values[missing_values > 0]

print(columns_with_missing_values)
# Out:
# pos-draftkings        717
# pos-fanduel           121
# pos-yahoo              47
# salary-draftkings     717
# salary-fanduel        121
#                      ...
# fp_yahoo_lag_2       1029
# fp_yahoo_lag_3       1530
# fp_yahoo_diff_1       521
# fp_yahoo_diff_2      1029
# fp_yahoo_diff_3      1530
# Length: 650, dtype: int64

# %%
all_predictions = []
all_true_values = []
all_game_ids = []
all_game_dates = []
all_player_ids = []
all_fanduel_salaries = []
all_draftkings_salaries = []
all_yahoo_salaries = []
all_fanduel_positions = []
all_draftkings_positions = []
all_yahoo_positions = []

scaler = MinMaxScaler(feature_range=(0, 1))
unique_weeks = df['league_week'].unique()

# %%
target = 'reb'
target_related_cols = same_game_cols
features = df.columns.difference(target_related_cols).tolist()

X = df[features]
y = df[target]

# %%
current_week = 8
num_weeks_for_training = 4
start_week = current_week - num_weeks_for_training
training_weeks = list(range(start_week, current_week))
time_steps = 4

# %%
X_train = X[X['league_week'].isin(training_weeks)]
y_train = y.loc[X_train.index]

X_test = X[X['league_week'] == current_week]
y_test = y.loc[X_test.index]

identifying_test_data = X_test[['player_name', 'game_date', 'game_id']]

X_train = X_train.drop(columns=['game_date', 'game_id'])
X_test = X_test.drop(columns=['game_date', 'game_id'])

# %%
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# %%
# Ensure y_train and y_test are reset
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# Create sequences
X_train_seq, y_train_seq = create_sequences(X_train, y_train, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, time_steps)

# %%
model = build_rnn_model((X_train_seq.shape[1], X_train_seq.shape[2]))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# prompt: i want to know all the different type for all features that are in X_train_seq

# Get the feature names from the original DataFrame (X_train)
feature_names = X_train.columns

# Iterate through the features and print their data types
for feature_name in feature_names:
  feature_data = X_train_seq[:,:, X_train.columns.get_loc(feature_name)]
  unique_types = set(type(element) for element in feature_data.flatten())
  print(f"Feature '{feature_name}' has the following data types: {unique_types}")
# Out:
# Feature 'ast_diff_1' has the following data types: {<class 'float'>}
# Feature 'ast_diff_2' has the following data types: {<class 'float'>}
# Feature 'ast_diff_3' has the following data types: {<class 'float'>}
# Feature 'ast_lag_1' has the following data types: {<class 'float'>}
# Feature 'ast_lag_2' has the following data types: {<class 'float'>}
# Feature 'ast_lag_3' has the following data types: {<class 'float'>}
# Feature 'ast_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'ast_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'ast_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'ast_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'ast_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'ast_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'ast_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ast_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_diff_1' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_diff_2' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_diff_3' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_lag_1' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_lag_2' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_lag_3' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ast_ratio_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'ast_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ast_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'ast_to_diff_1' has the following data types: {<class 'float'>}
# Feature 'ast_to_diff_2' has the following data types: {<class 'float'>}
# Feature 'ast_to_diff_3' has the following data types: {<class 'float'>}
# Feature 'ast_to_lag_1' has the following data types: {<class 'float'>}
# Feature 'ast_to_lag_2' has the following data types: {<class 'float'>}
# Feature 'ast_to_lag_3' has the following data types: {<class 'float'>}
# Feature 'ast_to_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ast_to_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'available_flag_diff_1' has the following data types: {<class 'float'>}
# Feature 'available_flag_diff_2' has the following data types: {<class 'float'>}
# Feature 'available_flag_diff_3' has the following data types: {<class 'float'>}
# Feature 'available_flag_lag_1' has the following data types: {<class 'float'>}
# Feature 'available_flag_lag_2' has the following data types: {<class 'float'>}
# Feature 'available_flag_lag_3' has the following data types: {<class 'float'>}
# Feature 'available_flag_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'available_flag_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'blk_diff_1' has the following data types: {<class 'float'>}
# Feature 'blk_diff_2' has the following data types: {<class 'float'>}
# Feature 'blk_diff_3' has the following data types: {<class 'float'>}
# Feature 'blk_lag_1' has the following data types: {<class 'float'>}
# Feature 'blk_lag_2' has the following data types: {<class 'float'>}
# Feature 'blk_lag_3' has the following data types: {<class 'float'>}
# Feature 'blk_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'blk_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'blka_diff_1' has the following data types: {<class 'float'>}
# Feature 'blka_diff_2' has the following data types: {<class 'float'>}
# Feature 'blka_diff_3' has the following data types: {<class 'float'>}
# Feature 'blka_lag_1' has the following data types: {<class 'float'>}
# Feature 'blka_lag_2' has the following data types: {<class 'float'>}
# Feature 'blka_lag_3' has the following data types: {<class 'float'>}
# Feature 'blka_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'blka_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'days_rest_int' has the following data types: {<class 'int'>}
# Feature 'dd2_diff_1' has the following data types: {<class 'float'>}
# Feature 'dd2_diff_2' has the following data types: {<class 'float'>}
# Feature 'dd2_diff_3' has the following data types: {<class 'float'>}
# Feature 'dd2_lag_1' has the following data types: {<class 'float'>}
# Feature 'dd2_lag_2' has the following data types: {<class 'float'>}
# Feature 'dd2_lag_3' has the following data types: {<class 'float'>}
# Feature 'dd2_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'dd2_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'def_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'def_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'def_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'def_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'def_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'def_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'def_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'def_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'dreb_diff_1' has the following data types: {<class 'float'>}
# Feature 'dreb_diff_2' has the following data types: {<class 'float'>}
# Feature 'dreb_diff_3' has the following data types: {<class 'float'>}
# Feature 'dreb_lag_1' has the following data types: {<class 'float'>}
# Feature 'dreb_lag_2' has the following data types: {<class 'float'>}
# Feature 'dreb_lag_3' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'dreb_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'dreb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'dreb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'e_def_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'e_net_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'e_off_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'e_pace_diff_1' has the following data types: {<class 'float'>}
# Feature 'e_pace_diff_2' has the following data types: {<class 'float'>}
# Feature 'e_pace_diff_3' has the following data types: {<class 'float'>}
# Feature 'e_pace_lag_1' has the following data types: {<class 'float'>}
# Feature 'e_pace_lag_2' has the following data types: {<class 'float'>}
# Feature 'e_pace_lag_3' has the following data types: {<class 'float'>}
# Feature 'e_pace_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'e_pace_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'e_tov_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'e_usg_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'efg_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'efg_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'efg_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'efg_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'efg_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'efg_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'efg_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'efg_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fg3_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fg3a_diff_1' has the following data types: {<class 'float'>}
# Feature 'fg3a_diff_2' has the following data types: {<class 'float'>}
# Feature 'fg3a_diff_3' has the following data types: {<class 'float'>}
# Feature 'fg3a_lag_1' has the following data types: {<class 'float'>}
# Feature 'fg3a_lag_2' has the following data types: {<class 'float'>}
# Feature 'fg3a_lag_3' has the following data types: {<class 'float'>}
# Feature 'fg3a_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fg3a_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fg3m_diff_1' has the following data types: {<class 'float'>}
# Feature 'fg3m_diff_2' has the following data types: {<class 'float'>}
# Feature 'fg3m_diff_3' has the following data types: {<class 'float'>}
# Feature 'fg3m_lag_1' has the following data types: {<class 'float'>}
# Feature 'fg3m_lag_2' has the following data types: {<class 'float'>}
# Feature 'fg3m_lag_3' has the following data types: {<class 'float'>}
# Feature 'fg3m_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fg3m_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fg_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'fg_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'fg_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'fg_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'fg_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'fg_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'fg_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fg_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fga_diff_1' has the following data types: {<class 'float'>}
# Feature 'fga_diff_2' has the following data types: {<class 'float'>}
# Feature 'fga_diff_3' has the following data types: {<class 'float'>}
# Feature 'fga_lag_1' has the following data types: {<class 'float'>}
# Feature 'fga_lag_2' has the following data types: {<class 'float'>}
# Feature 'fga_lag_3' has the following data types: {<class 'float'>}
# Feature 'fga_pg_diff_1' has the following data types: {<class 'float'>}
# Feature 'fga_pg_diff_2' has the following data types: {<class 'float'>}
# Feature 'fga_pg_diff_3' has the following data types: {<class 'float'>}
# Feature 'fga_pg_lag_1' has the following data types: {<class 'float'>}
# Feature 'fga_pg_lag_2' has the following data types: {<class 'float'>}
# Feature 'fga_pg_lag_3' has the following data types: {<class 'float'>}
# Feature 'fga_pg_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fga_pg_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fga_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fga_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fgm_diff_1' has the following data types: {<class 'float'>}
# Feature 'fgm_diff_2' has the following data types: {<class 'float'>}
# Feature 'fgm_diff_3' has the following data types: {<class 'float'>}
# Feature 'fgm_lag_1' has the following data types: {<class 'float'>}
# Feature 'fgm_lag_2' has the following data types: {<class 'float'>}
# Feature 'fgm_lag_3' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_diff_1' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_diff_2' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_diff_3' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_lag_1' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_lag_2' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_lag_3' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fgm_pg_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fgm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fgm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_diff_1' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_diff_2' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_diff_3' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_lag_1' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_lag_2' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_lag_3' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fp_draftkings_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_diff_1' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_diff_2' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_diff_3' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_lag_1' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_lag_2' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_lag_3' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fp_fanduel_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_diff_1' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_diff_2' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_diff_3' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_lag_1' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_lag_2' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_lag_3' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fp_yahoo_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'ft_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'ft_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'ft_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'ft_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'ft_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'ft_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'ft_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ft_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'fta_diff_1' has the following data types: {<class 'float'>}
# Feature 'fta_diff_2' has the following data types: {<class 'float'>}
# Feature 'fta_diff_3' has the following data types: {<class 'float'>}
# Feature 'fta_lag_1' has the following data types: {<class 'float'>}
# Feature 'fta_lag_2' has the following data types: {<class 'float'>}
# Feature 'fta_lag_3' has the following data types: {<class 'float'>}
# Feature 'fta_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'fta_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'ftm_diff_1' has the following data types: {<class 'float'>}
# Feature 'ftm_diff_2' has the following data types: {<class 'float'>}
# Feature 'ftm_diff_3' has the following data types: {<class 'float'>}
# Feature 'ftm_lag_1' has the following data types: {<class 'float'>}
# Feature 'ftm_lag_2' has the following data types: {<class 'float'>}
# Feature 'ftm_lag_3' has the following data types: {<class 'float'>}
# Feature 'ftm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ftm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'is_playoff' has the following data types: {<class 'int'>}
# Feature 'is_wl' has the following data types: {<class 'int'>}
# Feature 'league_week' has the following data types: {<class 'int'>}
# Feature 'minutes_played_diff_1' has the following data types: {<class 'float'>}
# Feature 'minutes_played_diff_2' has the following data types: {<class 'float'>}
# Feature 'minutes_played_diff_3' has the following data types: {<class 'float'>}
# Feature 'minutes_played_lag_1' has the following data types: {<class 'float'>}
# Feature 'minutes_played_lag_2' has the following data types: {<class 'float'>}
# Feature 'minutes_played_lag_3' has the following data types: {<class 'float'>}
# Feature 'minutes_played_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'minutes_played_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_diff_1' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_diff_2' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_diff_3' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_lag_1' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_lag_2' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_lag_3' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'nba_fantasy_pts_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'net_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'net_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'net_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'net_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'net_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'net_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'net_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'net_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'off_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'off_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'off_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'off_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'off_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'off_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'off_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'off_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'opponent' has the following data types: {<class 'str'>}
# Feature 'oreb_diff_1' has the following data types: {<class 'float'>}
# Feature 'oreb_diff_2' has the following data types: {<class 'float'>}
# Feature 'oreb_diff_3' has the following data types: {<class 'float'>}
# Feature 'oreb_lag_1' has the following data types: {<class 'float'>}
# Feature 'oreb_lag_2' has the following data types: {<class 'float'>}
# Feature 'oreb_lag_3' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'oreb_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'oreb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'oreb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pace_diff_1' has the following data types: {<class 'float'>}
# Feature 'pace_diff_2' has the following data types: {<class 'float'>}
# Feature 'pace_diff_3' has the following data types: {<class 'float'>}
# Feature 'pace_lag_1' has the following data types: {<class 'float'>}
# Feature 'pace_lag_2' has the following data types: {<class 'float'>}
# Feature 'pace_lag_3' has the following data types: {<class 'float'>}
# Feature 'pace_per40_diff_1' has the following data types: {<class 'float'>}
# Feature 'pace_per40_diff_2' has the following data types: {<class 'float'>}
# Feature 'pace_per40_diff_3' has the following data types: {<class 'float'>}
# Feature 'pace_per40_lag_1' has the following data types: {<class 'float'>}
# Feature 'pace_per40_lag_2' has the following data types: {<class 'float'>}
# Feature 'pace_per40_lag_3' has the following data types: {<class 'float'>}
# Feature 'pace_per40_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pace_per40_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pace_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pace_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_ast_2pm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_ast_3pm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_ast_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_ast_fgm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_ast_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_ast_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_ast_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_ast_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_ast_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_blk_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_blk_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_blk_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_blk_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_blk_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_blk_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_blk_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_blk_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_blka_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_blka_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_blka_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_blka_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_blka_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_blka_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_blka_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_blka_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_dreb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fg3a_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fg3m_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fga_2pt_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fga_3pt_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fga_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fga_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fga_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fga_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fga_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fga_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fga_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fga_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fgm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_fta_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_fta_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_fta_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_fta_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_fta_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_fta_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_fta_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_fta_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_ftm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_oreb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pf_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pf_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pf_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pf_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pf_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pf_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pf_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pf_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pfd_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_mr_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_2pt_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_3pt_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_fb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_ft_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_off_tov_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_paint_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_pts_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_pts_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_reb_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_reb_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_reb_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_reb_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_reb_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_reb_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_reb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_reb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_stl_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_stl_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_stl_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_stl_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_stl_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_stl_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_stl_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_stl_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_tov_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_tov_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_tov_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_tov_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_tov_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_tov_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_tov_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_tov_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_uast_2pm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_uast_3pm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_diff_1' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_diff_2' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_diff_3' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_lag_1' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_lag_2' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_lag_3' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pct_uast_fgm_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pf_diff_1' has the following data types: {<class 'float'>}
# Feature 'pf_diff_2' has the following data types: {<class 'float'>}
# Feature 'pf_diff_3' has the following data types: {<class 'float'>}
# Feature 'pf_lag_1' has the following data types: {<class 'float'>}
# Feature 'pf_lag_2' has the following data types: {<class 'float'>}
# Feature 'pf_lag_3' has the following data types: {<class 'float'>}
# Feature 'pf_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pf_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pfd_diff_1' has the following data types: {<class 'float'>}
# Feature 'pfd_diff_2' has the following data types: {<class 'float'>}
# Feature 'pfd_diff_3' has the following data types: {<class 'float'>}
# Feature 'pfd_lag_1' has the following data types: {<class 'float'>}
# Feature 'pfd_lag_2' has the following data types: {<class 'float'>}
# Feature 'pfd_lag_3' has the following data types: {<class 'float'>}
# Feature 'pfd_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pfd_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pie_diff_1' has the following data types: {<class 'float'>}
# Feature 'pie_diff_2' has the following data types: {<class 'float'>}
# Feature 'pie_diff_3' has the following data types: {<class 'float'>}
# Feature 'pie_lag_1' has the following data types: {<class 'float'>}
# Feature 'pie_lag_2' has the following data types: {<class 'float'>}
# Feature 'pie_lag_3' has the following data types: {<class 'float'>}
# Feature 'pie_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pie_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'player_name' has the following data types: {<class 'str'>}
# Feature 'plus_minus_diff_1' has the following data types: {<class 'float'>}
# Feature 'plus_minus_diff_2' has the following data types: {<class 'float'>}
# Feature 'plus_minus_diff_3' has the following data types: {<class 'float'>}
# Feature 'plus_minus_lag_1' has the following data types: {<class 'float'>}
# Feature 'plus_minus_lag_2' has the following data types: {<class 'float'>}
# Feature 'plus_minus_lag_3' has the following data types: {<class 'float'>}
# Feature 'plus_minus_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'plus_minus_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pos-draftkings' has the following data types: {<class 'float'>, <class 'str'>}
# Feature 'pos-fanduel' has the following data types: {<class 'float'>, <class 'str'>}
# Feature 'pos-yahoo' has the following data types: {<class 'float'>, <class 'str'>}
# Feature 'poss_diff_1' has the following data types: {<class 'float'>}
# Feature 'poss_diff_2' has the following data types: {<class 'float'>}
# Feature 'poss_diff_3' has the following data types: {<class 'float'>}
# Feature 'poss_lag_1' has the following data types: {<class 'float'>}
# Feature 'poss_lag_2' has the following data types: {<class 'float'>}
# Feature 'poss_lag_3' has the following data types: {<class 'float'>}
# Feature 'poss_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'poss_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'pts_diff_1' has the following data types: {<class 'float'>}
# Feature 'pts_diff_2' has the following data types: {<class 'float'>}
# Feature 'pts_diff_3' has the following data types: {<class 'float'>}
# Feature 'pts_lag_1' has the following data types: {<class 'float'>}
# Feature 'pts_lag_2' has the following data types: {<class 'float'>}
# Feature 'pts_lag_3' has the following data types: {<class 'float'>}
# Feature 'pts_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'pts_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'reb_diff_1' has the following data types: {<class 'float'>}
# Feature 'reb_diff_2' has the following data types: {<class 'float'>}
# Feature 'reb_diff_3' has the following data types: {<class 'float'>}
# Feature 'reb_lag_1' has the following data types: {<class 'float'>}
# Feature 'reb_lag_2' has the following data types: {<class 'float'>}
# Feature 'reb_lag_3' has the following data types: {<class 'float'>}
# Feature 'reb_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'reb_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'reb_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'reb_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'reb_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'reb_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'reb_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'reb_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'reb_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'reb_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'salary-draftkings' has the following data types: {<class 'float'>}
# Feature 'salary-fanduel' has the following data types: {<class 'float'>}
# Feature 'salary-yahoo' has the following data types: {<class 'float'>}
# Feature 'season_year' has the following data types: {<class 'str'>}
# Feature 'sp_work_def_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'sp_work_def_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'sp_work_net_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_diff_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_diff_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_diff_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_lag_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_lag_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_lag_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'sp_work_off_rating_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_diff_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_diff_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_diff_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_lag_1' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_lag_2' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_lag_3' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'sp_work_pace_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'starter' has the following data types: {<class 'int'>}
# Feature 'stl_diff_1' has the following data types: {<class 'float'>}
# Feature 'stl_diff_2' has the following data types: {<class 'float'>}
# Feature 'stl_diff_3' has the following data types: {<class 'float'>}
# Feature 'stl_lag_1' has the following data types: {<class 'float'>}
# Feature 'stl_lag_2' has the following data types: {<class 'float'>}
# Feature 'stl_lag_3' has the following data types: {<class 'float'>}
# Feature 'stl_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'stl_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'td3_diff_1' has the following data types: {<class 'float'>}
# Feature 'td3_diff_2' has the following data types: {<class 'float'>}
# Feature 'td3_diff_3' has the following data types: {<class 'float'>}
# Feature 'td3_lag_1' has the following data types: {<class 'float'>}
# Feature 'td3_lag_2' has the following data types: {<class 'float'>}
# Feature 'td3_lag_3' has the following data types: {<class 'float'>}
# Feature 'td3_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'td3_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'team_abbreviation' has the following data types: {<class 'str'>}
# Feature 'tm_tov_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'tm_tov_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'tov_diff_1' has the following data types: {<class 'float'>}
# Feature 'tov_diff_2' has the following data types: {<class 'float'>}
# Feature 'tov_diff_3' has the following data types: {<class 'float'>}
# Feature 'tov_lag_1' has the following data types: {<class 'float'>}
# Feature 'tov_lag_2' has the following data types: {<class 'float'>}
# Feature 'tov_lag_3' has the following data types: {<class 'float'>}
# Feature 'tov_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'tov_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'ts_pct_diff_1' has the following data types: {<class 'float'>}
# Feature 'ts_pct_diff_2' has the following data types: {<class 'float'>}
# Feature 'ts_pct_diff_3' has the following data types: {<class 'float'>}
# Feature 'ts_pct_lag_1' has the following data types: {<class 'float'>}
# Feature 'ts_pct_lag_2' has the following data types: {<class 'float'>}
# Feature 'ts_pct_lag_3' has the following data types: {<class 'float'>}
# Feature 'ts_pct_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'ts_pct_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'usage_rate_diff_1' has the following data types: {<class 'float'>}
# Feature 'usage_rate_diff_2' has the following data types: {<class 'float'>}
# Feature 'usage_rate_diff_3' has the following data types: {<class 'float'>}
# Feature 'usage_rate_lag_1' has the following data types: {<class 'float'>}
# Feature 'usage_rate_lag_2' has the following data types: {<class 'float'>}
# Feature 'usage_rate_lag_3' has the following data types: {<class 'float'>}
# Feature 'usage_rate_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'usage_rate_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_diff_1' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_diff_2' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_diff_3' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_lag_1' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_lag_2' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_lag_3' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'usg_pct_x_rolling_10_day_std' has the following data types: {<class 'float'>}
# Feature 'venue' has the following data types: {<class 'int'>}
# Feature 'wnba_fantasy_pts_diff_1' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_diff_2' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_diff_3' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_lag_1' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_lag_2' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_lag_3' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_rolling_10_day_avg' has the following data types: {<class 'float'>}
# Feature 'wnba_fantasy_pts_rolling_10_day_std' has the following data types: {<class 'float'>}

# %%
# print(X_train_seq.dtype)
# print(y_train_seq.dtype)
X_train_seq = X_train_seq.astype(np.float32)

X_train_seq.dtype
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-97896cd19366> in <cell line: 3>()
#       1 # print(X_train_seq.dtype)
#       2 # print(y_train_seq.dtype)
# ----> 3 X_train_seq = X_train_seq.astype(np.float32)
#       4
#       5 X_train_seq.dtype
#
# ValueError: could not convert string to float: 'Brooklyn'

# %%
model.fit(X_train_seq, y_train_seq, epochs=10, batch_size=32, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-2681f66a8576> in <cell line: 1>()
# ----> 1 model.fit(X_train_seq, y_train_seq, epochs=10, batch_size=32, verbose=0)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     106       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107   ctx.ensure_initialized()
# --> 108   return ops.EagerTensor(value, ctx.device_name, dtype)
#     109
#     110
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).

# %%
    for current_week in unique_weeks:
        start_week = current_week - num_weeks_for_training
        training_weeks = list(range(start_week, current_week))

        # Select training data (previous 4 weeks)
        X_train = X[X['league_week'].isin(training_weeks)]
        y_train = y.loc[X_train.index]

        # Select test data (current week)
        X_test = X[X['league_week'] == current_week]
        y_test = y.loc[X_test.index]

        if X_train.empty or X_test.empty:
            continue

        identifying_test_data = X_test[['player_name', 'game_date', 'game_id']]
        X_train = X_train.drop(columns=['game_date', 'game_id'])
        X_test = X_test.drop(columns=['game_date', 'game_id'])

        # Scale data
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        # Create sequences for training
        X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, time_steps)
        X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, time_steps)

        # Build and train the RNN model
        model = build_rnn_model((X_train_seq.shape[1], X_train_seq.shape[2]))
        model.fit(X_train_seq, y_train_seq, epochs=10, batch_size=32, verbose=0)

        # Make predictions
        y_pred = model.predict(X_test_seq)

        # Store the predictions and true values
        all_predictions.extend(y_pred.flatten())
        all_true_values.extend(y_test_seq)
        all_game_ids.extend(list(identifying_test_data['game_id'])[time_steps:])
        all_game_dates.extend(list(identifying_test_data['game_date'])[time_steps:])
        all_player_ids.extend(list(identifying_test_data['player_name'])[time_steps:])
        all_fanduel_salaries.extend(X_test['salary-draftkings'].values[time_steps:])
        all_draftkings_salaries.extend(X_test['salary-draftkings'].values[time_steps:])
        all_yahoo_salaries.extend(X_test['salary-yahoo'].values[time_steps:])
        all_fanduel_positions.extend(X_test['pos-draftkings'].values[time_steps:])
        all_draftkings_positions.extend(X_test['pos-draftkings'].values[time_steps:])
        all_yahoo_positions.extend(X_test['pos-yahoo'].values[time_steps:])

        if save_model:
            model_filename = f'{model_dir}/rnn_model_week_{current_week}_trained_on_{start_week}_to_{current_week - 1}.h5'
            model.save(model_filename)

        mse = mean_squared_error(y_test_seq, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_seq, y_pred)

        print(f'Training weeks: {training_weeks}')
        print(f'Test week: {current_week}')
        print(f'Mean Squared Error (MSE): {mse:.2f}')
        print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
        print(f'R-squared (R²): {r2:.2f}')
        print('')

    results_df = pd.DataFrame({
        'player_name': all_player_ids,
        'game_id': all_game_ids,
        'game_date': all_game_dates,
        'y': all_true_values,
        'y_pred': all_predictions,
        'fanduel_salary': all_fanduel_salaries,
        'draftkings_salary': all_draftkings_salaries,
        'yahoo_salary': all_yahoo_salaries,
        'fanduel_position': all_fanduel_positions,
        'draftkings_position': all_draftkings_positions,
        'yahoo_position': all_yahoo_positions,
    })

# %%
]

            print(f'Training RNN models for {cat}')
            print('---------------------------------')
            cat_results = rolling_train_test_rnn(X=X, y=y, df=df)
            cat_results.rename(columns={'y': cat, 'y_pred': f'{cat}_pred'}, inplace=True)
            if len(season_results) == 0:
                season_results = cat_results
            else:
                season_results = pd.merge(
                    season_results,
                    cat_results,
                    on=['player_name', 'game_date', 'game_id', 'fanduel_salary', 'draftkings_salary', 'yahoo_salary', 'draftkings_position', 'fanduel_position', 'yahoo_position'],
                    suffixes=('', f'_{df.columns.name}'))
            cat_results.to_csv(f'output_csv/{cat}_{season}_rnn_results.csv', index=False)

        all_seasons_results.append(season_results)

    combined_df = pd.concat(all_seasons_results, ignore_index=True)
    combined_df['fp_fanduel'] = combined_df.apply(lambda row: calculate_fp_fanduel(row), axis=1)
    combined_df['fp_fanduel_pred'] = combined_df.apply(lambda row: calculate_fp_fanduel(row, pred_mode=True), axis=1)

    combined_df['fp_yahoo'] = combined_df.apply(calculate_fp_yahoo, axis=1)
    combined_df['fp_yahoo_pred'] = combined_df.apply(lambda row: calculate_fp_yahoo(row, pred_mode=True), axis=1)

    combined_df['fp_draftkings'] = combined_df.apply(calculate_fp_draftkings, axis=1)
    combined_df['fp_draftkings_pred'] = combined_df.apply(lambda row: calculate_fp_draftkings(row, pred_mode=True),
                                                          axis=1)
    return combined_df

# %%
xt

# %% [markdown]
# # Take 2

# %%
df = pd.read_csv('gamelogs_salaries_2018-19_merged.csv')
df = df.drop('Unnamed: 0', axis=1)

# %%
df = df.sort_values(['game_date'], ascending=True)
df = assign_league_weeks(df)
df = clean_numeric_columns(df, same_game_cols)
df = add_time_dependent_features(df, rolling_window=rolling_window)
# Out:
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# ...
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)
# <ipython-input-59-d08f6c406a38>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_avg'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_rolling_{rolling_window}_day_std'] = gb.transform(
# <ipython-input-59-d08f6c406a38>:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_1'] = gb.shift(1)
# <ipython-input-59-d08f6c406a38>:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_2'] = gb.shift(2)
# <ipython-input-59-d08f6c406a38>:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_3'] = gb.shift(3)
# <ipython-input-59-d08f6c406a38>:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_1'] = gb.diff(1)
# <ipython-input-59-d08f6c406a38>:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_2'] = gb.diff(2)
# <ipython-input-59-d08f6c406a38>:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_diff_3'] = gb.diff(3)

# %%
# Convert game_date to datetime
df['game_date'] = pd.to_datetime(df['game_date'])

# Define categorical columns
cat_cols = ['team_abbreviation', 'player_name', 'opponent', 'pos-draftkings', 'pos-fanduel', 'pos-yahoo']

# Label encode categorical variables
label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
current_week = 8
num_weeks_for_training = 4
start_week = current_week - num_weeks_for_training
training_weeks = list(range(start_week, current_week))
time_steps = 4

# Split the data into training and testing sets
X_train = df[df['league_week'].isin(training_weeks)]
y_train = df[df['league_week'].isin(training_weeks)][target]
X_test = df[df['league_week'] == current_week]
y_test = df[df['league_week'] == current_week][target]

# Reset index for y_train and y_test
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# Drop non-feature columns
X_train = X_train.drop(columns=['game_date', 'game_id'])
X_test = X_test.drop(columns=['game_date', 'game_id'])

# %%
X_train_seq, y_train_seq = create_sequences(X_train, y_train, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, time_steps)

# %%
inputs = []
embeddings = []
for col in cat_cols:
    input_dim = df[col].nunique()  # number of unique categories
    output_dim = min(50, input_dim // 2)  # embedding size, you can adjust this
    input_layer = Input(shape=(1,), name=col)
    embedding_layer = Embedding(input_dim=input_dim, output_dim=output_dim, input_length=1)(input_layer)
    embedding_layer = Flatten()(embedding_layer)
    inputs.append(input_layer)
    embeddings.append(embedding_layer)

# Combine all embeddings
combined_embeddings = Concatenate()(embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
rnn_input = Input(shape=(time_steps, X_train_seq.shape[2] - len(cat_cols)), name='rnn_input')
x = LSTM(64, return_sequences=True)(rnn_input)
x = LSTM(32)(x)
x = Dense(32, activation='relu')(x)

# %%
x = Concatenate()([x, combined_embeddings])

# %%
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
output = Dense(1, activation='linear')(x)

# %%
# Define the model
model = Model(inputs=[rnn_input] + inputs, outputs=output)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Model summary
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ rnn_input (InputLayer)    │ (None, 4, 838)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ team_abbreviation         │ (None, 1)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ player_name (InputLayer)  │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ opponent (InputLayer)     │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pos-draftkings            │ (None, 1)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pos-fanduel (InputLayer)  │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pos-yahoo (InputLayer)    │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_2 (LSTM)             │ (None, 4, 64)          │        231,168 │ rnn_input[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_6 (Embedding)   │ (None, 1, 15)          │            450 │ team_abbreviation[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_7 (Embedding)   │ (None, 1, 50)          │         26,050 │ player_name[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_8 (Embedding)   │ (None, 1, 15)          │            450 │ opponent[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_9 (Embedding)   │ (None, 1, 5)           │             55 │ pos-draftkings[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_10 (Embedding)  │ (None, 1, 3)           │             18 │ pos-fanduel[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_11 (Embedding)  │ (None, 1, 3)           │             18 │ pos-yahoo[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_3 (LSTM)             │ (None, 32)             │         12,416 │ lstm_2[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_6 (Flatten)       │ (None, 15)             │              0 │ embedding_6[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_7 (Flatten)       │ (None, 50)             │              0 │ embedding_7[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_8 (Flatten)       │ (None, 15)             │              0 │ embedding_8[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_9 (Flatten)       │ (None, 5)              │              0 │ embedding_9[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_10 (Flatten)      │ (None, 3)              │              0 │ embedding_10[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_11 (Flatten)      │ (None, 3)              │              0 │ embedding_11[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          1,056 │ lstm_3[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 91)             │              0 │ flatten_6[0][0],       │
# │ (Concatenate)             │                        │                │ flatten_7[0][0],       │
# │                           │                        │                │ flatten_8[0][0],       │
# │                           │                        │                │ flatten_9[0][0],       │
# │                           │                        │                │ flatten_10[0][0],      │
# │                           │                        │                │ flatten_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 123)            │              0 │ dense_2[0][0],         │
# │ (Concatenate)             │                        │                │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 64)             │          7,936 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 64)             │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1)              │             65 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 279,682 (1.07 MB)
#  Trainable params: 279,682 (1.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train_inputs = {col: X_train[col].values for col in cat_cols}
X_test_inputs = {col: X_test[col].values for col in cat_cols}

# %%
X_train_inputs['rnn_input'] = X_train_seq
X_test_inputs['rnn_input'] = X_test_seq

# %%
# Train the model
model.fit(X_train_inputs, y_train_seq, epochs=10, batch_size=32, verbose=1)

# Evaluate the model
model.evaluate(X_test_inputs, y_test_seq)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-997aaf13d897> in <cell line: 2>()
#       1 # Train the model
# ----> 2 model.fit(X_train_inputs, y_train_seq, epochs=10, batch_size=32, verbose=1)
#       3
#       4 # Evaluate the model
#       5 model.evaluate(X_test_inputs, y_test_seq)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/data_adapter_utils.py in check_data_cardinality(data)
#     112             )
#     113             msg += f"'{label}' sizes: {sizes}\n"
# --> 114         raise ValueError(msg)
#     115
#     116
#
# ValueError: Data cardinality is ambiguous. Make sure all arrays contain the same number of samples.'x' sizes: 4171, 4171, 4171, 4171, 4171, 4167, 4171
# 'y' sizes: 4167
